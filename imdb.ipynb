# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a series of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.loc[:,'duration'].mean()
# Out:
# 120.97957099080695

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.loc[:,['duration','title']].sort_values('duration')
# Out:
#      duration                                          title
# 389        64                                         Freaks
# 338        66                            Battleship Potemkin
# 258        67                    The Cabinet of Dr. Caligari
# 293        68                                      Duck Soup
# 88         68                                        The Kid
# 742        69                                      Following
# 351        70                                   Frankenstein
# 938        75                            Alice in Wonderland
# 405        75                      The Bride of Frankenstein
# 303        76                 The Nightmare Before Christmas
# 713        78                                The Jungle Book
# 864        78                                          [Rec]
# 489        78                     The Triplets of Belleville
# 535        79                                          Zelig
# ...

# %%
movies.sort_values('duration')
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
# Answer: 
movies.hist(column='duration', bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x103f94a20>]],
#       dtype=object)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
movies.boxplot(column='duration')

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies.groupby('content_rating').agg({'title':'count'})
# Out:
#                 title
# content_rating
# APPROVED           47
# G                  32
# GP                  3
# NC-17               7
# NOT RATED          65
# PASSED              7
# PG                123
# PG-13             189
# R                 460
# TV-MA               1
# UNRATED            38
# X                   4

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
# Answer:
rating_bar = movies.groupby('content_rating').agg({'title':'count'}).plot(kind = 'bar')
rating_bar.set_xlabel('Movie rating')
rating_bar.set_ylabel('Frequency')
rating_bar.set_title('Frequency of Movies by Rating')
# Out:
# Text(0.5,1,'Frequency of Movies by Rating')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
new_movies = movies.copy()

# %%
# Answer:
new_movies.loc[:,'content_rating'].replace(to_replace=['NOT RATED','APPROVED', 'PASSED', 'GP'], value='UNRATED',inplace=True)
new_movies.groupby('content_rating').agg({'title':'count'})
# Out:
#                 title
# content_rating
# G                  32
# NC-17               7
# PG                123
# PG-13             189
# R                 460
# TV-MA               1
# UNRATED           160
# X                   4

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
new_movies.loc[:,'content_rating'].replace(to_replace=['TV-MA', 'X'], value='NC-17',inplace=True)
new_movies.groupby('content_rating').agg({'title':'count'})
# Out:
#                 title
# content_rating
# G                  32
# NC-17              12
# PG                123
# PG-13             189
# R                 460
# UNRATED           160

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
new_movies.isna().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
new_movies.loc[new_movies.loc[:,'content_rating'].isna() == True,:]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
new_movies.iloc[187,2] = 'PG'
new_movies.iloc[649,2] = 'PG'
new_movies.iloc[936,2] = 'PG-13'
new_movies.iloc[[187,649,936],:]

# Found the ratings online myself. What would "reasonable" values be for this if I didn't look these up?
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid             PG
# 649          7.7                   Where Eagles Dare             PG
# 936          7.4                           True Grit          PG-13
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer:
new_movies.loc[(new_movies.loc[:,'duration'] > 120), 'star_rating'].mean()
# Out:
# 7.953669724770622

# %%
new_movies.loc[(new_movies.loc[:,'duration'] < 120), 'star_rating'].mean()
# Out:
# 7.838666666666657

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
new_movies.groupby('star_rating').agg({'duration':'mean'}).plot(kind='bar')

# %%
new_movies.plot(kind='scatter', x='duration', y='star_rating')

# %%
import seaborn as sns
sns.lmplot(x="duration", y='star_rating', data=movies);
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies.groupby('genre').agg({'duration':'mean'})
# Out:
#              duration
# genre
# Action     126.485294
# Adventure  134.840000
# Animation   96.596774
# Biography  131.844156
# Comedy     107.602564
# Crime      122.298387
# Drama      126.539568
# Family     107.500000
# Fantasy    112.000000
# Film-Noir   97.333333
# History     66.000000
# Horror     102.517241
# Mystery    115.625000
# Sci-Fi     109.000000
# Thriller   114.200000
# Western    136.666667

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer: 
new_movies.groupby('content_rating').agg({'duration':'mean'})
# Out:
#                   duration
# content_rating
# G               112.343750
# NC-17           116.250000
# PG              115.600000
# PG-13           127.200000
# R               122.163043
# UNRATED         116.475000

# %%
ax = new_movies.groupby('content_rating').agg({'duration':'mean'}).plot(kind='barh');

# %% [markdown]
# #### Find the title of the movie with the highest star rating in each genre

# %%
# THis is the code given as 'starter code' 

movies.groupby('genre')['star_rating'].max()
# Out:
# genre
# Action       9.0
# Adventure    8.9
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.3
# Drama        8.9
# Family       7.9
# Fantasy      7.7
# Film-Noir    8.3
# History      8.0
# Horror       8.6
# Mystery      8.6
# Sci-Fi       8.2
# Thriller     8.0
# Western      8.9
# Name: star_rating, dtype: float64

# %%
#This is how I would have done it 
movies.groupby(['genre']).agg({'star_rating':'max'})
# Out:
#            star_rating
# genre
# Action             9.0
# Adventure          8.9
# Animation          8.6
# Biography          8.9
# Comedy             8.6
# Crime              9.3
# Drama              8.9
# Family             7.9
# Fantasy            7.7
# Film-Noir          8.3
# History            8.0
# Horror             8.6
# Mystery            8.6
# Sci-Fi             8.2
# Thriller           8.0
# Western            8.9

# %%
# I first tried adding 'title' into the list of columns
# Seems wrong

movies.groupby('genre')['title','star_rating'].max()
# Out:
#                                          title  star_rating
# genre
# Action                                 Yojimbo          9.0
# Adventure                            True Grit          8.9
# Animation                       Wreck-It Ralph          8.6
# Biography                        Walk the Line          8.9
# Comedy                              Zombieland          8.6
# Crime                                   Zodiac          9.3
# Drama                                     Zulu          8.9
# Family     Willy Wonka & the Chocolate Factory          7.9
# Fantasy              The City of Lost Children          7.7
# Film-Noir                        The Third Man          8.3
# History                    Battleship Potemkin          8.0
# Horror                                   [Rec]          8.6
# Mystery                                Vertigo          8.6
# Sci-Fi           The Day the Earth Stood Still          8.2
# Thriller             The Man Who Knew Too Much          8.0
# ...

# %%
# Then I tried adding title to the `.groupby()` and also `sort_value()`
# Also seems wrong

movies.groupby(['genre','title']).agg({'star_rating':'max'}).sort_values('star_rating', ascending=False)
# Out:
#                                                              star_rating
# genre     title
# Crime     The Shawshank Redemption                                   9.3
#           The Godfather                                              9.2
#           The Godfather: Part II                                     9.1
# Action    The Dark Knight                                            9.0
# Drama     Fight Club                                                 8.9
#           12 Angry Men                                               8.9
# Biography Schindler's List                                           8.9
# Adventure The Lord of the Rings: The Return of the King              8.9
# Western   The Good, the Bad and the Ugly                             8.9
# Crime     Pulp Fiction                                               8.9
# Action    Inception                                                  8.8
# Adventure The Lord of the Rings: The Fellowship of the Ring          8.8
# ...

# %%
# Finally, I found this solution online... using a `transform()` method and creating a boolean
# index. 

idx = movies.groupby('genre')['star_rating'].transform(max) == movies.loc[:,'star_rating']
movies.loc[idx,['title', 'star_rating', 'genre']].sort_values('genre')
# Out:
#                                              title  star_rating      genre
# 3                                  The Dark Knight          9.0     Action
# 7    The Lord of the Rings: The Return of the King          8.9  Adventure
# 30                                   Spirited Away          8.6  Animation
# 8                                 Schindler's List          8.9  Biography
# 35                                    Modern Times          8.6     Comedy
# 29                                     City Lights          8.6     Comedy
# 25                               Life Is Beautiful          8.6     Comedy
# 0                         The Shawshank Redemption          9.3      Crime
# 5                                     12 Angry Men          8.9      Drama
# 9                                       Fight Club          8.9      Drama
# 468                     E.T. the Extra-Terrestrial          7.9     Family
# ...

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# First I tried writing a for loop to determine multiples
# This did not seem to work

data = [np.random.randint(1,10) for a in range(10)]
print(data)

duples = []
seen = {}
for x in data:
    if x not in seen:
        seen[x] = 1
    else:
        if seen[x] == 1:
            duples.append(x)
        seen[x] += 1
print(duples)
# Out:
# [1, 7, 2, 2, 4, 4, 7, 8, 4, 2]
# [2, 4, 7]

# %%
# This approach needs more work, I did not understand that the .apply already has a for-loop baked
# in. Want to understand this approach better for using lambda functions to look at data. 

def find_dupl(col):
    duples =[]
    seen = {}
    for x in col:
        if x not in seen:
            seen[x] == 1
        else:
            if seen[x] == 1:
                duples.append(x)
            seen[x] += 1
    return duples

movies.loc[:,'title'].apply(find_dupl) #, axis='columns')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-16b3bf6b0a83> in <module>()
#      12     return duples
#      13
# ---> 14 movies.loc[:,'title'].apply(find_dupl) #, axis='columns')
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3192             else:
#    3193                 values = self.astype(object).values
# -> 3194                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3195
#    3196         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-150-16b3bf6b0a83> in find_dupl(col)
#       5     for x in col:
#       6         if x not in seen:
# ----> 7             seen[x] == 1
#       8         else:
#       9             if seen[x] == 1:
#
# KeyError: 'T'

# %%
# I scrapped the above aproached and tried grouping by distinct values of columns and filter by greater than one. 

movies2 = movies.groupby('title').agg({'title':'count'})
movies_dups = movies2.loc[movies2.loc[:,'title']>1,:]
movies_dups
# Out:
#                                  title
# title
# Dracula                              2
# Les Miserables                       2
# The Girl with the Dragon Tattoo      2
# True Grit                            2

# %%
#GENERAL QUESTION

# WHy does this work: 
movies.title.value_counts()

# But this doesn't

movies.loc[:'title'].value_counts()
# Out:
# True Grit                                                 2
# Dracula                                                   2
# The Girl with the Dragon Tattoo                           2
# Les Miserables                                            2
# Match Point                                               1
# Master and Commander: The Far Side of the World           1
# Harry Potter and the Half-Blood Prince                    1
# The Searchers                                             1
# This Is Spinal Tap                                        1
# The Bridge on the River Kwai                              1
# Gandhi                                                    1
# Batman Begins                                             1
# Boyz n the Hood                                           1
# Beetlejuice                                               1
# Nosferatu                                                 1
# The Curse of the Were-Rabbit                              1
# ...

# %%
#SAME QUESTION

# WHy does this work:

movies.title.value_counts()[movies.title.value_counts() > 1]

# But this doesn't:

movies.title.value_counts().loc[[movies.title.value_counts() > 1], :]

#When is it better to use `.` syntax vs. .loc[:,:]. I only 'learned' .loc but it looks like it is necessary 
#to know the others df inspection syntaxes as well?
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-282-bb81f9ce594d> in <module>()
# ----> 1 movies.title.value_counts().loc[[movies.title.value_counts() > 1], :]
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     873
#     874         # no multi-index, so validate all of the indexers
# --> 875         self._has_valid_tuple(tup)
#     876
#     877         # ugly hack for GH #836
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _has_valid_tuple(self, key)
# ...

# %%
dup_list = list(movies.title.value_counts()[movies.title.value_counts() > 1].index)

bool_dup = movies.loc[:,'title'].isin(dup_list)

movies.loc[bool_dup,:]

#Answer: It seems like all the duplicates are actually remakes
# Out:
#      star_rating                            title content_rating      genre  \
# 466          7.9  The Girl with the Dragon Tattoo              R      Crime
# 482          7.8  The Girl with the Dragon Tattoo              R      Crime
# 662          7.7                        True Grit          PG-13  Adventure
# 678          7.7                   Les Miserables          PG-13      Drama
# 703          7.6                          Dracula       APPROVED     Horror
# 905          7.5                          Dracula              R     Horror
# 924          7.5                   Les Miserables          PG-13      Crime
# 936          7.4                        True Grit            NaN  Adventure
#
#      duration                                        actors_list  max_rating
# 466       158  [u'Daniel Craig', u'Rooney Mara', u'Christophe...         9.3
# 482       152  [u'Michael Nyqvist', u'Noomi Rapace', u'Ewa Fr...         9.3
# ...

# %%
# Another General Question:

# Why doesn't this work? 

movies.loc[dup_list,'title']

# SHouldn't I be able to pass a list of row indexes into the first half of .loc?
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-304-5882b35e2f59> in <module>()
#       3 # Why doesn't this work?
#       4
# ----> 5 movies.loc[dup_list,'title']
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
# ...

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# **You only need to choose one of the options below.** However, solving for multiple options would count as "extra credit" that could e.g. raise your score from a 2 ("meets expectations") to a 3 ("exceeds expectations").

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:
movies.loc[:,'genre'].value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
more_than_ten = ['Drama', 'Comedy', 'Action','Crime','Biography','Adventure','Animation','Horror','Mystery']
movie_mask = movies.loc[:, 'genre'].isin(more_than_ten)

movies.loc[movie_mask, :].groupby('genre').agg({'star_rating':'mean'})
# Out:
#            star_rating
# genre
# Action        7.884559
# Adventure     7.933333
# Animation     7.914516
# Biography     7.862338
# Comedy        7.822436
# Crime         7.916935
# Drama         7.902518
# Horror        7.806897
# Mystery       7.975000

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
genre_counts = movies.genre.value_counts()
relevant_genres = list(genre_counts[genre_counts>10].index)

movie_mask = movies.loc[:, 'genre'].isin(relevant_genres)

movies.loc[movie_mask, :].groupby('genre').agg({'star_rating':'mean'})
# Out:
#            star_rating
# genre
# Action        7.884559
# Adventure     7.933333
# Animation     7.914516
# Biography     7.862338
# Comedy        7.822436
# Crime         7.916935
# Drama         7.902518
# Horror        7.806897
# Mystery       7.975000

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
movies3 = movies.groupby('genre').agg({'star_rating':'mean', 'genre':'count'})
movies3.loc[movies3.loc[:,'genre']>10,:]
# Out:
#            star_rating  genre
# genre
# Action        7.884559    136
# Adventure     7.933333     75
# Animation     7.914516     62
# Biography     7.862338     77
# Comedy        7.822436    156
# Crime         7.916935    124
# Drama         7.902518    278
# Horror        7.806897     29
# Mystery       7.975000     16

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# It seems I already did this is option 3

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
